# %%
import requests
import pandas as pd
import mysql.connector
import os
from pandarallel import pandarallel
from utils import image
from airflow import DAG
from airflow.operators.python import PythonOperator

# %%
# Initialise

root_path = '/Users/nitinnandansingh/Documents/workspace/e-commerce_data_pipeline'
images_dir = os.path.join(root_path, 'assets/product_images')
print(images_dir)

# Initialize pandarallel
pandarallel.initialize(progress_bar=True)
# Out:
# /Users/nitinnandansingh/Documents/workspace/e-commerce_data_pipeline/assets/product_images
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.

# %%
def fetch_products_data():
    response = requests.get("https://fakestoreapi.com/products")
    data = response.json()
    return pd.DataFrame(data)

# %%
def fetch_users_data():
    response = requests.get("https://fakestoreapi.com/users")
    data = response.json()
    return pd.DataFrame(data)

# %%
products_df = fetch_products_data()
users_df = fetch_users_data()

# %% [markdown]
# ## Explore products data

# %%
products_df.head(3)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
#
#                         rating
# 0  {'rate': 3.9, 'count': 120}
# 1  {'rate': 4.1, 'count': 259}
# 2  {'rate': 4.7, 'count': 500}

# %%
products_df.columns.to_list()
# Out:
# ['id', 'title', 'price', 'description', 'category', 'image', 'rating']

# %%
products_df.describe(include='all').fillna("")
# Out:
#              id                                              title  \
# count      20.0                                                 20
# unique                                                          20
# top              Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...
# freq                                                             1
# mean       10.5
# std     5.91608
# min         1.0
# 25%        5.75
# 50%        10.5
# 75%       15.25
# max        20.0
#
#              price                                        description  \
# count         20.0                                                 20
# unique                                                             20
# top                 Your perfect pack for everyday use and walks i...
# freq                                                                1
# mean       162.046
# std     272.220532
# min           7.95
# 25%          15.24
# 50%          56.49
# 75%       110.9625
# max         999.99
#
#            category                                              image  \
# count            20                                                 20
# unique            4                                                 20
# top     electronics  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# freq              6                                                  1
# mean
# std
# min
# 25%
# 50%
# 75%
# max
#
#                              rating
# count                            20
# unique                           20
# top     {'rate': 3.9, 'count': 120}
# freq                              1
# mean
# std
# min
# 25%
# 50%
# 75%
# max

# %%
products_df['image'][0]
# Out:
# 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_.jpg'

# %% [markdown]
# ### Download images

# %%
def download_image(url, images_dir):
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()
        filename = os.path.join(images_dir, url.split('/')[-1])
        with open(filename, 'wb') as file:
            for chunk in response.iter_content(1024):
                file.write(chunk)
        return filename
    except Exception as e:
        print(f"Error downloading {url}: {e}")
        return None

def parallel_download(url):
    save_dir = images_dir
    return download_image(url, save_dir)

products_df['images_dir'] = products_df['image'].parallel_apply(parallel_download)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=3), Label(value='0 / 3'))), HBox(c…

# %%
products_df.head(5)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...
#
#                         rating  \
# 0  {'rate': 3.9, 'count': 120}
# 1  {'rate': 4.1, 'count': 259}
# 2  {'rate': 4.7, 'count': 500}
# 3  {'rate': 2.1, 'count': 430}
# 4  {'rate': 4.6, 'count': 400}
#
#                                           images_dir
# 0  /Users/nitinnandansingh/Documents/workspace/e-...
# 1  /Users/nitinnandansingh/Documents/workspace/e-...
# 2  /Users/nitinnandansingh/Documents/workspace/e-...
# 3  /Users/nitinnandansingh/Documents/workspace/e-...
# 4  /Users/nitinnandansingh/Documents/workspace/e-...

# %%
products_df.drop_duplicates(subset=['id'], inplace=True)
# products_df.dropna(inplace=True)

# %%
products_df['rating'][0]
# Out:
# {'rate': 3.9, 'count': 120}

# %%
def get_count_of_ratings(dict_val):
    return dict_val['count']

def get_ratings(dict_val):
    return dict_val['rate']

# %%
products_df['count_of_ratings'] = products_df['rating'].parallel_apply(get_count_of_ratings)

# products_df['count_of_ratings'] = products_df['rating']['count']
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=3), Label(value='0 / 3'))), HBox(c…

# %%
products_df['rating'] = products_df['rating'].parallel_apply(get_ratings)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=3), Label(value='0 / 3'))), HBox(c…

# %%
products_df.head(3)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
#
#                                                image  rating  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...     3.9
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...     4.1
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...     4.7
#
#                                           images_dir  count_of_ratings
# 0  /Users/nitinnandansingh/Documents/workspace/e-...               120
# 1  /Users/nitinnandansingh/Documents/workspace/e-...               259
# 2  /Users/nitinnandansingh/Documents/workspace/e-...               500

# %%
# validate images
products_df['image_valid'] = products_df['images_dir'].parallel_apply(image.is_valid_image)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=3), Label(value='0 / 3'))), HBox(c…

# %%
products_df[products_df['image_valid']==False]
# Out:
# Empty DataFrame
# Columns: [id, title, price, description, category, image, rating, images_dir, count_of_ratings, image_valid]
# Index: []

# %%
products_df.drop(columns=['image_valid'], axis=1, inplace=True)
products_df.head(3)
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
#
#                                                image  rating  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...     3.9
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...     4.1
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...     4.7
#
#                                           images_dir  count_of_ratings
# 0  /Users/nitinnandansingh/Documents/workspace/e-...               120
# 1  /Users/nitinnandansingh/Documents/workspace/e-...               259
# 2  /Users/nitinnandansingh/Documents/workspace/e-...               500

# %%
products_df.columns.to_list()
# Out:
# ['id',
#  'title',
#  'price',
#  'description',
#  'category',
#  'image',
#  'rating',
#  'images_dir',
#  'count_of_ratings']

# %%
def check_data_types(df):
    # Get the data types of each column
    data_types = df.dtypes

    # Print the data type of each column
    for column, dtype in data_types.items():
        print(f"Column '{column}' has data type '{dtype}'.")

# Call the function with your DataFrame
check_data_types(products_df)
# Out:
# Column 'id' has data type 'int64'.
# Column 'title' has data type 'object'.
# Column 'price' has data type 'float64'.
# Column 'description' has data type 'object'.
# Column 'category' has data type 'object'.
# Column 'image' has data type 'object'.
# Column 'rating' has data type 'float64'.
# Column 'images_dir' has data type 'object'.
# Column 'count_of_ratings' has data type 'int64'.

# %% [markdown]
# ## Explore users data

# %%
users_df.head(3)
# Out:
#                                              address  id               email  \
# 0  {'geolocation': {'lat': '-37.3159', 'long': '8...   1      john@gmail.com
# 1  {'geolocation': {'lat': '-37.3159', 'long': '8...   2  morrison@gmail.com
# 2  {'geolocation': {'lat': '40.3467', 'long': '-3...   3     kevin@gmail.com
#
#     username   password                                            name  \
# 0      johnd    m38rmF$        {'firstname': 'john', 'lastname': 'doe'}
# 1   mor_2314     83r5^_  {'firstname': 'david', 'lastname': 'morrison'}
# 2  kevinryan  kev02937@      {'firstname': 'kevin', 'lastname': 'ryan'}
#
#             phone  __v
# 0  1-570-236-7033    0
# 1  1-570-236-7033    0
# 2  1-567-094-1345    0

# %%
users_df.columns.to_list()
# Out:
# ['address', 'id', 'email', 'username', 'password', 'name', 'phone', '__v']

# %%
set(users_df['__v'].to_list())
# Out:
# {0}

# %%
users_df.describe(include='all').fillna('')
# Out:
#                                                   address       id  \
# count                                                  10     10.0
# unique                                                 10
# top     {'geolocation': {'lat': '-37.3159', 'long': '8...
# freq                                                    1
# mean                                                           5.5
# std                                                        3.02765
# min                                                            1.0
# 25%                                                           3.25
# 50%                                                            5.5
# 75%                                                           7.75
# max                                                           10.0
#
#                  email username password  \
# count               10       10       10
# unique              10       10       10
# top     john@gmail.com    johnd  m38rmF$
# freq                 1        1        1
# mean
# std
# min
# 25%
# 50%
# 75%
# max
#
#                                             name           phone   __v
# count                                         10              10  10.0
# unique                                        10               9
# top     {'firstname': 'john', 'lastname': 'doe'}  1-570-236-7033
# freq                                           1               2
# mean                                                               0.0
# std                                                                0.0
# min                                                                0.0
# 25%                                                                0.0
# 50%                                                                0.0
# 75%                                                                0.0
# max                                                                0.0

# %%
users_df.drop(columns=['__v'], axis=1, inplace=True)

# %%
def check_data_types(df):
    # Get the data types of each column
    data_types = df.dtypes

    # Print the data type of each column
    for column, dtype in data_types.items():
        print(f"Column '{column}' has data type '{dtype}'.")

# Call the function with your DataFrame
check_data_types(users_df)
# Out:
# Column 'address' has data type 'object'.
# Column 'id' has data type 'int64'.
# Column 'email' has data type 'object'.
# Column 'username' has data type 'object'.
# Column 'password' has data type 'object'.
# Column 'name' has data type 'object'.
# Column 'phone' has data type 'object'.

# %%
type(users_df['address'][0]['number'])
# Out:
# int

# %%
address_df = users_df['address'].apply(pd.Series)
address_df
# Out:
#                                  geolocation         city            street  \
# 0     {'lat': '-37.3159', 'long': '81.1496'}     kilcoole          new road
# 1     {'lat': '-37.3159', 'long': '81.1496'}     kilcoole         Lovers Ln
# 2     {'lat': '40.3467', 'long': '-30.1310'}      Cullman        Frances Ct
# 3     {'lat': '50.3467', 'long': '-20.1310'}  San Antonio  Hunters Creek Dr
# 4     {'lat': '40.3467', 'long': '-40.1310'}  san Antonio          adams St
# 5     {'lat': '20.1677', 'long': '-10.6789'}      el paso       prospect st
# 6      {'lat': '10.3456', 'long': '20.6419'}       fresno         saddle st
# 7      {'lat': '50.3456', 'long': '10.6419'}         mesa     vally view ln
# 8     {'lat': '40.12456', 'long': '20.5419'}        miami      avondale ave
# 9  {'lat': '30.24788', 'long': '-20.545419'}   fort wayne      oak lawn ave
#
#    number     zipcode
# 0    7682  12926-3874
# 1    7267  12926-3874
# 2      86  29567-1452
# 3    6454  98234-1734
# 4     245  80796-1234
# 5     124  12346-0456
# 6    1342  96378-0245
# 7    1342  96378-0245
# 8     345  96378-0245
# 9     526  10256-4532

# %%
users_df = pd.concat([users_df, address_df], axis=1).drop('address', axis=1)
users_df
# Out:
#    id               email   username      password  \
# 0   1      john@gmail.com      johnd       m38rmF$
# 1   2  morrison@gmail.com   mor_2314        83r5^_
# 2   3     kevin@gmail.com  kevinryan     kev02937@
# 3   4       don@gmail.com     donero        ewedon
# 4   5     derek@gmail.com      derek      jklg*_56
# 5   6   david_r@gmail.com    david_r      3478*#54
# 6   7    miriam@gmail.com     snyder      f238&@*$
# 7   8   william@gmail.com    hopkins  William56$hj
# 8   9      kate@gmail.com     kate_h      kfejk@*_
# 9  10    jimmie@gmail.com   jimmie_k     klein*#%*
#
#                                               name           phone  \
# 0         {'firstname': 'john', 'lastname': 'doe'}  1-570-236-7033
# 1   {'firstname': 'david', 'lastname': 'morrison'}  1-570-236-7033
# 2       {'firstname': 'kevin', 'lastname': 'ryan'}  1-567-094-1345
# 3        {'firstname': 'don', 'lastname': 'romer'}  1-765-789-6734
# 4     {'firstname': 'derek', 'lastname': 'powell'}  1-956-001-1945
# 5    {'firstname': 'david', 'lastname': 'russell'}  1-678-345-9856
# 6    {'firstname': 'miriam', 'lastname': 'snyder'}  1-123-943-0563
# 7  {'firstname': 'william', 'lastname': 'hopkins'}  1-478-001-0890
# 8        {'firstname': 'kate', 'lastname': 'hale'}  1-678-456-1934
# 9     {'firstname': 'jimmie', 'lastname': 'klein'}  1-104-001-4567
#
#                                  geolocation         city            street  \
# 0     {'lat': '-37.3159', 'long': '81.1496'}     kilcoole          new road
# 1     {'lat': '-37.3159', 'long': '81.1496'}     kilcoole         Lovers Ln
# 2     {'lat': '40.3467', 'long': '-30.1310'}      Cullman        Frances Ct
# 3     {'lat': '50.3467', 'long': '-20.1310'}  San Antonio  Hunters Creek Dr
# 4     {'lat': '40.3467', 'long': '-40.1310'}  san Antonio          adams St
# 5     {'lat': '20.1677', 'long': '-10.6789'}      el paso       prospect st
# 6      {'lat': '10.3456', 'long': '20.6419'}       fresno         saddle st
# 7      {'lat': '50.3456', 'long': '10.6419'}         mesa     vally view ln
# 8     {'lat': '40.12456', 'long': '20.5419'}        miami      avondale ave
# 9  {'lat': '30.24788', 'long': '-20.545419'}   fort wayne      oak lawn ave
#
#    number     zipcode
# 0    7682  12926-3874
# 1    7267  12926-3874
# 2      86  29567-1452
# 3    6454  98234-1734
# 4     245  80796-1234
# 5     124  12346-0456
# 6    1342  96378-0245
# 7    1342  96378-0245
# 8     345  96378-0245
# 9     526  10256-4532

# %%
users_df['lat'] = users_df['geolocation'].apply(lambda x: x['lat'])
users_df['long'] = users_df['geolocation'].apply(lambda x: x['long'])
users_df.drop(['geolocation'], axis=1, inplace=True)

# %%
users_df
# Out:
#    id               email   username      password  \
# 0   1      john@gmail.com      johnd       m38rmF$
# 1   2  morrison@gmail.com   mor_2314        83r5^_
# 2   3     kevin@gmail.com  kevinryan     kev02937@
# 3   4       don@gmail.com     donero        ewedon
# 4   5     derek@gmail.com      derek      jklg*_56
# 5   6   david_r@gmail.com    david_r      3478*#54
# 6   7    miriam@gmail.com     snyder      f238&@*$
# 7   8   william@gmail.com    hopkins  William56$hj
# 8   9      kate@gmail.com     kate_h      kfejk@*_
# 9  10    jimmie@gmail.com   jimmie_k     klein*#%*
#
#                                               name           phone  \
# 0         {'firstname': 'john', 'lastname': 'doe'}  1-570-236-7033
# 1   {'firstname': 'david', 'lastname': 'morrison'}  1-570-236-7033
# 2       {'firstname': 'kevin', 'lastname': 'ryan'}  1-567-094-1345
# 3        {'firstname': 'don', 'lastname': 'romer'}  1-765-789-6734
# 4     {'firstname': 'derek', 'lastname': 'powell'}  1-956-001-1945
# 5    {'firstname': 'david', 'lastname': 'russell'}  1-678-345-9856
# 6    {'firstname': 'miriam', 'lastname': 'snyder'}  1-123-943-0563
# 7  {'firstname': 'william', 'lastname': 'hopkins'}  1-478-001-0890
# 8        {'firstname': 'kate', 'lastname': 'hale'}  1-678-456-1934
# 9     {'firstname': 'jimmie', 'lastname': 'klein'}  1-104-001-4567
#
#           city            street  number     zipcode       lat        long
# 0     kilcoole          new road    7682  12926-3874  -37.3159     81.1496
# 1     kilcoole         Lovers Ln    7267  12926-3874  -37.3159     81.1496
# 2      Cullman        Frances Ct      86  29567-1452   40.3467    -30.1310
# 3  San Antonio  Hunters Creek Dr    6454  98234-1734   50.3467    -20.1310
# 4  san Antonio          adams St     245  80796-1234   40.3467    -40.1310
# 5      el paso       prospect st     124  12346-0456   20.1677    -10.6789
# 6       fresno         saddle st    1342  96378-0245   10.3456     20.6419
# 7         mesa     vally view ln    1342  96378-0245   50.3456     10.6419
# 8        miami      avondale ave     345  96378-0245  40.12456     20.5419
# 9   fort wayne      oak lawn ave     526  10256-4532  30.24788  -20.545419

# %%
check_data_types(users_df)
# Out:
# Column 'id' has data type 'int64'.
# Column 'email' has data type 'object'.
# Column 'username' has data type 'object'.
# Column 'password' has data type 'object'.
# Column 'name' has data type 'object'.
# Column 'phone' has data type 'object'.
# Column 'city' has data type 'object'.
# Column 'street' has data type 'object'.
# Column 'number' has data type 'int64'.
# Column 'zipcode' has data type 'object'.
# Column 'lat' has data type 'object'.
# Column 'long' has data type 'object'.

# %%
products_df.to_excel("products.xlsx", index=False)
users_df.to_excel("users.xlsx", index=False)

# %%
products_df.columns.to_list()
# Out:
# ['id',
#  'title',
#  'price',
#  'description',
#  'category',
#  'image',
#  'rating',
#  'images_dir',
#  'count_of_ratings']

# %%
conn = mysql.connector.connect(
        host="localhost",
        user="ecommerce_user",
        password="password",
        database="ecommerce_data"
    )

# %%
cursor = conn.cursor()
res = cursor.execute("select * from ecommerce_data;")
res
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/anaconda3/envs/ecommerce/lib/python3.12/site-packages/mysql/connector/connection_cext.py:697, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     696         query = query.encode("utf-8")
# --> 697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#     700         buffered=buffered,
#     701         raw_as_string=raw_as_string,
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'ecommerce_data.ecommerce_data' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[3], line 2
#       1 cursor = conn.cursor()
# ----> 2 res = cursor.execute("select * from ecommerce_data;")
#       3 res
#
# File ~/anaconda3/envs/ecommerce/lib/python3.12/site-packages/mysql/connector/cursor_cext.py:372, in CMySQLCursor.execute(self, operation, params, multi)
#     367             raise ProgrammingError(
#     368                 "Not all parameters were used in the SQL statement"
#     369             )
#     371 try:
# --> 372     result = self._cnx.cmd_query(
#     373         stmt,
#     374         raw=self._raw,
#     375         buffered=self._buffered,
#     376         raw_as_string=self._raw_as_string,
#     377     )
#     378 except MySQLInterfaceError as err:
#     379     raise get_mysql_exception(
#     380         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     381     ) from err
#
# File ~/anaconda3/envs/ecommerce/lib/python3.12/site-packages/mysql/connector/opentelemetry/context_propagation.py:111, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#     108     cnx.query_attrs_append(value=(TRACEPARENT_HEADER_NAME, tp_header))
#     110 try:
# --> 111     result = method(cnx, *args, **kwargs)
#     112 finally:
#     113     if tp_header is not None:
#
# File ~/anaconda3/envs/ecommerce/lib/python3.12/site-packages/mysql/connector/connection_cext.py:705, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     697     self._cmysql.query(
#     698         query,
#     699         raw=raw,
#    (...)
#     702         query_attrs=self.query_attrs,
#     703     )
#     704 except MySQLInterfaceError as err:
# --> 705     raise get_mysql_exception(
#     706         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     707     ) from err
#     708 except AttributeError as err:
#     709     addr = (
#     710         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     711     )
#
# ProgrammingError: 1146 (42S02): Table 'ecommerce_data.ecommerce_data' doesn't exist

# %%
def store_data(df, table_name):
    conn = mysql.connector.connect(
        host="localhost",
        user="ecommerce_user",
        password="password",
        database="ecommerce_data"
    )
    cursor = conn.cursor()
    for _, row in df.iterrows():
        if table_name == "products":
            cursor.execute("""
                INSERT INTO products (id, title, price, description, category, image)
                VALUES (%s, %s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE
                title = VALUES(title),
                price = VALUES(price),
                description = VALUES(description),
                category = VALUES(category),
                image = VALUES(image);
            """,tuple(row))
        elif table_name == "users":
            cursor.execute("""
                INSERT INTO users (id, email, username, password, name, address, phone)
                VALUES (%s, %s, %s, %s, %s, %s, %s)
                ON DUPLICATE KEY UPDATE
                email = VALUES(email),
                username = VALUES(username),
                password = VALUES(password),
                name = VALUES(name),
                address = VALUES(address),
                phone = VALUES(phone);
            """, tuple(row))
            conn.commit()
            cursor.close()
            conn.close()

# %%
def run_pipeline():
    products_df = fetch_products_data()
    store_data(products_df, "products")

    users_df = fetch_users_data()
    store_data(users_df, "users")
